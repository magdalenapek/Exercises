# %% [markdown]
# # DataFrame Analysis Exercise
#
# **Import the `bestsellers.csv` dataset and use it to answer the following questions:**
#
# * Find the lowest User Rating in the DF
# * Find the highest Price in the DF
# * What is the average User Rating?
# * What the average User Rating of the first 5 rows?
# * What User Review score appeared the most?
# * What is the total (sum) of all the values in the Reviews column?
# * How many different authors are featured in the dataset?
# * Which author wrote the most number of books on the list?  How many did they write?

# %%
import pandas as pd 
bestsellers = pd.read_csv("C:/Users/magda/udemy_course/DataAnalysisCourseMaterials/DataAnalysis/data/bestsellers.csv")
bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %%
bestsellers.min()
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                      Abraham Verghese
# User Rating                              3.3
# Reviews                                   37
# Price                                      0
# Year                                    2009
# Genre                                Fiction
# dtype: object

# %%
bestsellers.max()
# Out:
# Name           You Are a Badass: How to Stop Doubting Your Gr...
# Author                                              Zhi Gang Sha
# User Rating                                                  4.9
# Reviews                                                    87841
# Price                                                        105
# Year                                                        2019
# Genre                                                Non Fiction
# dtype: object

# %%
bestsellers.mean()
# Out:
# C:\Users\magda\AppData\Local\Temp\ipykernel_20412\1813816453.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   bestsellers.mean()
# User Rating        4.618364
# Reviews        11953.281818
# Price             13.100000
# Year            2014.000000
# dtype: float64

# %%
bestsellers.head(5).mean()
# Out:
# C:\Users\magda\AppData\Local\Temp\ipykernel_20412\2420701358.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   bestsellers.head(5).mean()
# User Rating        4.7
# Reviews        13494.0
# Price             12.6
# Year            2016.2
# dtype: float64

# %%
bestsellers.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
bestsellers.mode()
# Out:
#                                                  Name       Author  \
# 0   Publication Manual of the American Psychologic...  Jeff Kinney
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
#
#     User Rating  Reviews  Price  Year        Genre
# 0           4.8   8580.0    8.0  2009  Non Fiction
# 1           NaN      NaN    NaN  2010          NaN
# 2           NaN      NaN    NaN  2011          NaN
# 3           NaN      NaN    NaN  2012          NaN
# 4           NaN      NaN    NaN  2013          NaN
# 5           NaN      NaN    NaN  2014          NaN
# 6           NaN      NaN    NaN  2015          NaN
# 7           NaN      NaN    NaN  2016          NaN
# 8           NaN      NaN    NaN  2017          NaN
# 9           NaN      NaN    NaN  2018          NaN
# 10          NaN      NaN    NaN  2019          NaN

# %%
bestsellers.sum()
# Out:
# Name           10-Day Green Smoothie Cleanse11/22/63: A Novel...
# Author         JJ SmithStephen KingJordan B. PetersonGeorge O...
# User Rating                                               2540.1
# Reviews                                                  6574305
# Price                                                       7205
# Year                                                     1107700
# Genre          Non FictionFictionNon FictionFictionNon Fictio...
# dtype: object

# %%
bestsellers.describe(include=["O"])
# Out:
#                                                      Name       Author  \
# count                                                 550          550
# unique                                                351          248
# top     Publication Manual of the American Psychologic...  Jeff Kinney
# freq                                                   10           12
#
#               Genre
# count           550
# unique            2
# top     Non Fiction
# freq            310

# %%
bestsellers["Name"]
# Out:
# 0                          10-Day Green Smoothie Cleanse
# 1                                      11/22/63: A Novel
# 2                12 Rules for Life: An Antidote to Chaos
# 3                                 1984 (Signet Classics)
# 4      5,000 Awesome Facts (About Everything!) (Natio...
#                              ...
# 545         Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546    You Are a Badass: How to Stop Doubting Your Gr...
# 547    You Are a Badass: How to Stop Doubting Your Gr...
# 548    You Are a Badass: How to Stop Doubting Your Gr...
# 549    You Are a Badass: How to Stop Doubting Your Gr...
# Name: Name, Length: 550, dtype: object

# %%
bestsellers[["Name", "User Rating"]]
# Out:
#                                                   Name  User Rating
# 0                        10-Day Green Smoothie Cleanse          4.7
# 1                                    11/22/63: A Novel          4.6
# 2              12 Rules for Life: An Antidote to Chaos          4.7
# 3                               1984 (Signet Classics)          4.7
# 4    5,000 Awesome Facts (About Everything!) (Natio...          4.8
# ..                                                 ...          ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)          4.9
# 546  You Are a Badass: How to Stop Doubting Your Gr...          4.7
# 547  You Are a Badass: How to Stop Doubting Your Gr...          4.7
# 548  You Are a Badass: How to Stop Doubting Your Gr...          4.7
# 549  You Are a Badass: How to Stop Doubting Your Gr...          4.7
#
# [550 rows x 2 columns]
